# %% [markdown]
# <a href="https://colab.research.google.com/github/h124577999-art/dsd/blob/main/ssd0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import streamlit as st
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.patches import Rectangle, Circle
import base64

# --- 網頁標題與說明 ---
st.set_page_config(layout="wide")
st.title("🛡️ 戰術防禦模擬系統 (SUT vs Traditional)")
st.sidebar.header("戰術參數設定")

# --- 側邊欄互動參數 ---
e_count = st.sidebar.slider("敵軍數量", 5, 30, 12)
e_speed = st.sidebar.slider("敵軍進攻速度", 0.5, 2.0, 1.15)
sut_hit_p = st.sidebar.slider("SUT 攔截率", 0.5, 1.0, 0.88)
trad_hit_p = st.sidebar.slider("傳統組攔截率", 0.1, 0.8, 0.42)
sut_dist = st.sidebar.slider("SUT 偵測範圍", 10, 30, 18)

# --- 核心模擬引擎 (封裝為函式以便重新計算) ---
def run_simulation(mode, e_num, e_spd, hit_p, d_lim):
    results = []
    # 這裡放入您定案的模擬邏輯 (為了簡潔，此處略過重複的計算代碼)
    # ... (執行 100 次模擬並產出數據) ...
    return data # 回傳 100 次的 health 與 casualty 數據

# --- 介面佈局 ---
col1, col2 = st.columns([1, 1])

if st.sidebar.button("🚀 開始模擬運算"):
    with st.spinner('正在進行 100 次戰術模擬並生成動畫...'):
        # 1. 執行運算
        # data_trad = run_simulation("trad", ...)
        # data_sut = run_simulation("sut", ...)

        # 2. 顯示統計圖表 (2x2 粗直方條圖)
        st.subheader("📊 統計數據分析 (每 10 次模擬平均值)")
        fig_stat, axs = plt.subplots(2, 2, figsize=(12, 8))
        # ... (繪製您定案的粗直方條圖代碼) ...
        st.pyplot(fig_stat)

        # 3. 生成動畫並匯出
        st.subheader("🎬 實時戰術接戰動畫")
        # ... (生成動畫代碼，移除外框數值) ...
        # 將動畫存為 gif 或 mp4 顯示在網頁上
        ani.save('temp_sim.gif', writer='pillow', fps=20)

        file_ = open("temp_sim.gif", "rb")
        contents = file_.read()
        data_url = base64.b64encode(contents).decode("utf-8")
        file_.close()
        st.markdown(f'<img src="data:image/gif;base64,{data_url}" width="100%">', unsafe_64=True)
